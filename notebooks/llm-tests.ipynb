# %% [markdown]
# # LLM Tests
#
# * this
# * that
#
# * [x] this is a checkbox
#
# ## second heading
# this is test
#
# ### third heading
# this is test
#
# This is `inline code` example.
#
# This is multiline code example:
# ```python
# def my_test():
#     pass
# ```
#
# ==hello==
#
# ```json
# {"this":
#     {"that":"there"}
# }
# ```
#
# ---

# %%
model = "Qwen/Qwen3.6-35B-A3B-FP8"
api_key = "your_api_key"
base_url = "https://vllm.pixolut.com/v1"
role = "You are a highly intelligent assistant helping a supremely qualified academic. Please respond to all user queries in English and there is no need to over explain things unless required. You should consider responses carefully before providing them. Use Australian English when responding."
instructions = "Keep responses concise and professional."

from LightAgent import LightAgent

agent = LightAgent(
    model=model,
    api_key=api_key,
    base_url=base_url,
    role=role,
    instructions=instructions
)

# Run a query
response = agent.run("Hello, who are you?")
print(response)
